# %%
# read a raw image file
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
# %matplotlib inline

# read in the image
image = mpimg.imread('./images/waymo_car.jfif')
# show the image
plt.imshow(image)
